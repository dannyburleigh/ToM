# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Arc
import seaborn as sns

# %matplotlib inline

data = pd.read_csv("D:\Matches\elanga_United_Wolves_23052021.csv")

data.head()
# Out:
#       Team  Player    Event  Mins  Secs   X   Y  X2  Y2
# 0  Man Utd  Elanga    Touch     0     0  13  42   -   -
# 1  Man Utd  Elanga    Touch     0     0  24   3   -   -
# 2  Man Utd  Elanga     Pass     0     0  25   6  36  30
# 3  Man Utd  Elanga    Touch     0     0  11  40   -   -
# 4  Man Utd  Elanga  Dribble     0     0  12  40  13  50

# %%
data[data['Player']=='HT']
# Out:
#        Team Player  Event  Mins  Secs   X   Y X2 Y2
# 45  Man Utd     HT  Touch     0    23  50  50  -  -

# %%
first_half = data.loc[:44,:]
second_half = data.loc[46:,:]
first_half['X2'] = first_half['X2'].replace('-', 0).astype(int)
first_half['Y2'] = first_half['Y2'].replace('-', 0).astype(int)
second_half['X2'] = second_half['X2'].replace('-', 0).astype(int)
second_half['Y2'] = second_half['Y2'].replace('-', 0).astype(int)
# Out:
# C:\Users\danny\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\danny\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\danny\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
first_half.head()
# Out:
#       Team  Player    Event  Mins  Secs   X   Y  X2  Y2
# 0  Man Utd  Elanga    Touch     0     0  13  42   0   0
# 1  Man Utd  Elanga    Touch     0     0  24   3   0   0
# 2  Man Utd  Elanga     Pass     0     0  25   6  36  30
# 3  Man Utd  Elanga    Touch     0     0  11  40   0   0
# 4  Man Utd  Elanga  Dribble     0     0  12  40  13  50

# %%
first_half['X'] = 100-first_half['X']
second_half['Y'] = 100-second_half['Y']
first_half['X2'] = 100-first_half['X2']
second_half['Y2'] = 100-second_half['Y2']

first_half = first_half[['Player','Event','X','Y','X2','Y2']]
# Out:
# C:\Users\danny\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\danny\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\danny\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
second_half = second_half[['Player','Event','X','Y','X2','Y2']]

# %%
first_half.columns = second_half.columns
data = pd.concat([first_half, second_half], axis=0, ignore_index=True)

data
# Out:
#     Player            Event   X   Y   X2   Y2
# 0   Elanga            Touch  87  42  100    0
# 1   Elanga            Touch  76   3  100    0
# 2   Elanga             Pass  75   6   64   30
# 3   Elanga            Touch  89  40  100    0
# 4   Elanga          Dribble  88  40   87   50
# ..     ...              ...  ..  ..  ...  ...
# 83  Elanga      Pass unsucc  58   3   37    7
# 84  Elanga     Dribble tack  37   8   43    8
# 85  Elanga  Touch lost poss  91  14    0  100
# 86  Elanga  Touch lost poss  70  61    0  100
# 87  Elanga      Pass unsucc  18  14   25    3
#
# [88 rows x 6 columns]

# %%
data['Y'].max()
# Out:
# 97

# %%
fig, ax = plt.subplots()
fig.set_size_inches(14,4)

#Plot One - distinct areas with few lines
plt.subplot(121)
sns.kdeplot(data["X"],data["Y"], shade="True", n_levels=5)

#Plot Two - fade lines with more of them
plt.subplot(122)
sns.kdeplot(data["X"],data["Y"], shade="True", n_levels=40)

plt.show()
# Out:
# C:\Users\danny\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\danny\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data
# Out:
#     Player            Event   X   Y   X2   Y2
# 0   Elanga            Touch  87  42  100    0
# 1   Elanga            Touch  76   3  100    0
# 2   Elanga             Pass  75   6   64   30
# 3   Elanga            Touch  89  40  100    0
# 4   Elanga          Dribble  88  40   87   50
# ..     ...              ...  ..  ..  ...  ...
# 83  Elanga      Pass unsucc  58   3   37    7
# 84  Elanga     Dribble tack  37   8   43    8
# 85  Elanga  Touch lost poss  91  14    0  100
# 86  Elanga  Touch lost poss  70  61    0  100
# 87  Elanga      Pass unsucc  18  14   25    3
#
# [88 rows x 6 columns]

# %%
data['X'] = data['X']*1.3
data['Y'] = data['Y']*0.9
data['X2'] = data['X2']*1.3
data['Y2'] = data['Y2']*0.9

# %%
data
# Out:
#     Player            Event      X     Y     X2    Y2
# 0   Elanga            Touch  113.1  37.8  130.0   0.0
# 1   Elanga            Touch   98.8   2.7  130.0   0.0
# 2   Elanga             Pass   97.5   5.4   83.2  27.0
# 3   Elanga            Touch  115.7  36.0  130.0   0.0
# 4   Elanga          Dribble  114.4  36.0  113.1  45.0
# ..     ...              ...    ...   ...    ...   ...
# 83  Elanga      Pass unsucc   75.4   2.7   48.1   6.3
# 84  Elanga     Dribble tack   48.1   7.2   55.9   7.2
# 85  Elanga  Touch lost poss  118.3  12.6    0.0  90.0
# 86  Elanga  Touch lost poss   91.0  54.9    0.0  90.0
# 87  Elanga      Pass unsucc   23.4  12.6   32.5   2.7
#
# [88 rows x 6 columns]

# %%
#Create figure
fig=plt.figure()
fig.set_size_inches(7, 5)
ax=fig.add_subplot(1,1,1)

#Pitch Outline & Centre Line
plt.plot([0,0],[0,90], color="black")
plt.plot([0,130],[90,90], color="black")
plt.plot([130,130],[90,0], color="black")
plt.plot([130,0],[0,0], color="black")
plt.plot([65,65],[0,90], color="black")

#Left Penalty Area
plt.plot([16.5,16.5],[65,25],color="black")
plt.plot([0,16.5],[65,65],color="black")
plt.plot([16.5,0],[25,25],color="black")

#Right Penalty Area
plt.plot([130,113.5],[65,65],color="black")
plt.plot([113.5,113.5],[65,25],color="black")
plt.plot([113.5,130],[25,25],color="black")

#Left 6-yard Box
plt.plot([0,5.5],[54,54],color="black")
plt.plot([5.5,5.5],[54,36],color="black")
plt.plot([5.5,0.5],[36,36],color="black")

#Right 6-yard Box
plt.plot([130,124.5],[54,54],color="black")
plt.plot([124.5,124.5],[54,36],color="black")
plt.plot([124.5,130],[36,36],color="black")

#Prepare Circles
centreCircle = plt.Circle((65,45),9.15,color="black",fill=False)
centreSpot = plt.Circle((65,45),0.8,color="black")
leftPenSpot = plt.Circle((11,45),0.8,color="black")
rightPenSpot = plt.Circle((119,45),0.8,color="black")

#Draw Circles
ax.add_patch(centreCircle)
ax.add_patch(centreSpot)
ax.add_patch(leftPenSpot)
ax.add_patch(rightPenSpot)

#Prepare Arcs
leftArc = Arc((11,45),height=18.3,width=18.3,angle=0,theta1=310,theta2=50,color="black")
rightArc = Arc((119,45),height=18.3,width=18.3,angle=0,theta1=130,theta2=230,color="black")

#Draw Arcs
ax.add_patch(leftArc)
ax.add_patch(rightArc)

#Tidy Axes
plt.axis('off')

sns.kdeplot(data["X"],data["Y"], shade=True,n_levels=20)
plt.ylim(0, 90)
plt.xlim(0, 130)
plt.title("Anthony Elanga vs Wolves heatmap 23/5/21")


#Display Pitch
plt.show()
# Out:
# C:\Users\danny\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Plot dribbles

# %%
#Get dribbles
dribbles = data[data['Event'].str.contains('Dribble')].reset_index()

# %%
dribbles
# Out:
#    index  Player         Event      X     Y     X2    Y2
# 0      4  Elanga       Dribble  114.4  36.0  113.1  45.0
# 1     18  Elanga  Dribble succ   91.0   1.8   91.0  19.8
# 2     24  Elanga  Dribble succ   62.4   2.7   52.0  10.8
# 3     29  Elanga  Dribble succ   98.8  14.4  104.0  19.8
# 4     32  Elanga  Dribble tack   89.7   6.3  102.7  23.4
# 5     53  Elanga  Dribble tack  117.0  10.8  123.5  21.6
# 6     56  Elanga  Dribble tack   32.5  24.3   63.7  18.0
# 7     60  Elanga  Dribble succ  101.4  71.1  110.5  79.2
# 8     69  Elanga  Dribble tack   62.4  71.1   65.0  84.6
# 9     84  Elanga  Dribble tack   48.1   7.2   55.9   7.2

# %%
#Create figure
fig=plt.figure()
fig.set_size_inches(7, 5)
ax=fig.add_subplot(1,1,1)

#Pitch Outline & Centre Line
plt.plot([0,0],[0,90], color="black")
plt.plot([0,130],[90,90], color="black")
plt.plot([130,130],[90,0], color="black")
plt.plot([130,0],[0,0], color="black")
plt.plot([65,65],[0,90], color="black")

#Left Penalty Area
plt.plot([16.5,16.5],[65,25],color="black")
plt.plot([0,16.5],[65,65],color="black")
plt.plot([16.5,0],[25,25],color="black")

#Right Penalty Area
plt.plot([130,113.5],[65,65],color="black")
plt.plot([113.5,113.5],[65,25],color="black")
plt.plot([113.5,130],[25,25],color="black")

#Left 6-yard Box
plt.plot([0,5.5],[54,54],color="black")
plt.plot([5.5,5.5],[54,36],color="black")
plt.plot([5.5,0.5],[36,36],color="black")

#Right 6-yard Box
plt.plot([130,124.5],[54,54],color="black")
plt.plot([124.5,124.5],[54,36],color="black")
plt.plot([124.5,130],[36,36],color="black")

#Prepare Circles
centreCircle = plt.Circle((65,45),9.15,color="black",fill=False)
centreSpot = plt.Circle((65,45),0.8,color="black")
leftPenSpot = plt.Circle((11,45),0.8,color="black")
rightPenSpot = plt.Circle((119,45),0.8,color="black")

#Draw Circles
ax.add_patch(centreCircle)
ax.add_patch(centreSpot)
ax.add_patch(leftPenSpot)
ax.add_patch(rightPenSpot)

#Prepare Arcs
leftArc = Arc((11,45),height=18.3,width=18.3,angle=0,theta1=310,theta2=50,color="black")
rightArc = Arc((119,45),height=18.3,width=18.3,angle=0,theta1=130,theta2=230,color="black")

#Draw Arcs
ax.add_patch(leftArc)
ax.add_patch(rightArc)

#Tidy Axes
plt.axis('off')

for i in range(len(dribbles)):
    plt.plot([int(dribbles["X"][i]),int(dribbles["X2"][i])],[int(dribbles["Y"][i]),int(dribbles["Y2"][i])], color="blue")
    plt.plot(int(dribbles["X"][i]),int(dribbles["Y"][i]),"o", color="green")
plt.ylim(0, 90)
plt.xlim(0, 130)
plt.title("Anthony Elanga vs Wolves dribbles 23/5/21")


#Display Pitch
plt.show()

# %%
dribbles['X'].mean()
# Out:
# 81.77

# %%
#Get dribbles
dribbles = data[data['Event'].str.contains('Dribble')].reset_index()

#Create figure
fig=plt.figure()
fig.set_size_inches(7, 5)
ax=fig.add_subplot(1,1,1)

#Pitch Outline & Centre Line
plt.plot([0,0],[0,90], color="black")
plt.plot([0,130],[90,90], color="black")
plt.plot([130,130],[90,0], color="black")
plt.plot([130,0],[0,0], color="black")
plt.plot([65,65],[0,90], color="black")

#Left Penalty Area
plt.plot([16.5,16.5],[65,25],color="black")
plt.plot([0,16.5],[65,65],color="black")
plt.plot([16.5,0],[25,25],color="black")

#Right Penalty Area
plt.plot([130,113.5],[65,65],color="black")
plt.plot([113.5,113.5],[65,25],color="black")
plt.plot([113.5,130],[25,25],color="black")

#Left 6-yard Box
plt.plot([0,5.5],[54,54],color="black")
plt.plot([5.5,5.5],[54,36],color="black")
plt.plot([5.5,0.5],[36,36],color="black")

#Right 6-yard Box
plt.plot([130,124.5],[54,54],color="black")
plt.plot([124.5,124.5],[54,36],color="black")
plt.plot([124.5,130],[36,36],color="black")

#Prepare Circles
centreCircle = plt.Circle((65,45),9.15,color="black",fill=False)
centreSpot = plt.Circle((65,45),0.8,color="black")
leftPenSpot = plt.Circle((11,45),0.8,color="black")
rightPenSpot = plt.Circle((119,45),0.8,color="black")

#Draw Circles
ax.add_patch(centreCircle)
ax.add_patch(centreSpot)
ax.add_patch(leftPenSpot)
ax.add_patch(rightPenSpot)

#Prepare Arcs
leftArc = Arc((11,45),height=18.3,width=18.3,angle=0,theta1=310,theta2=50,color="black")
rightArc = Arc((119,45),height=18.3,width=18.3,angle=0,theta1=130,theta2=230,color="black")

#Draw Arcs
ax.add_patch(leftArc)
ax.add_patch(rightArc)

#Tidy Axes
plt.axis('off')


for i in range(len(dribbles)):
    plt.arrow(dribbles['X'][i], dribbles['Y'][i], dribbles['X2'][i]-dribbles['X'][i], dribbles['Y2'][i]-dribbles['Y'][i],  color='r', length_includes_head=True, head_width=1, head_length=1, width=0.25)

    
plt.ylim(0, 90)
plt.xlim(0, 130)
plt.title("Anthony Elanga vs Wolves dribbles 23/5/2 | Attacking to right")


#Display Pitch
plt.show()

# %%
dribbles
# Out:
#    index  Player         Event      X     Y     X2    Y2
# 0      4  Elanga       Dribble  114.4  36.0  113.1  45.0
# 1     18  Elanga  Dribble succ   91.0   1.8   91.0  19.8
# 2     24  Elanga  Dribble succ   62.4   2.7   52.0  10.8
# 3     29  Elanga  Dribble succ   98.8  14.4  104.0  19.8
# 4     32  Elanga  Dribble tack   89.7   6.3  102.7  23.4
# 5     53  Elanga  Dribble tack  117.0  10.8  123.5  21.6
# 6     56  Elanga  Dribble tack   32.5  24.3   63.7  18.0
# 7     60  Elanga  Dribble succ  101.4  71.1  110.5  79.2
# 8     69  Elanga  Dribble tack   62.4  71.1   65.0  84.6
# 9     84  Elanga  Dribble tack   48.1   7.2   55.9   7.2

# %% [markdown]
# # Shooting

# %%
#Get dribbles
shots = data[data['Event'].isin(['Shot on target','Shot off target','Goal'])].reset_index()

# %%
shots
# Out:
#    index  Player            Event      X     Y     X2    Y2
# 0      5  Elanga  Shot off target  114.4  48.6  128.7  50.4
# 1     10  Elanga             Goal  123.5  40.5  128.7  45.0
# 2     80  Elanga  Shot off target  102.7  26.1  130.0  37.8

# %%
#Create figure
fig=plt.figure()
fig.set_size_inches(7, 5)
ax=fig.add_subplot(1,1,1)

#Pitch Outline & Centre Line
plt.plot([0,0],[0,90], color="black")
plt.plot([0,130],[90,90], color="black")
plt.plot([130,130],[90,0], color="black")
plt.plot([130,0],[0,0], color="black")
plt.plot([65,65],[0,90], color="black")

#Left Penalty Area
plt.plot([16.5,16.5],[65,25],color="black")
plt.plot([0,16.5],[65,65],color="black")
plt.plot([16.5,0],[25,25],color="black")

#Right Penalty Area
plt.plot([130,113.5],[65,65],color="black")
plt.plot([113.5,113.5],[65,25],color="black")
plt.plot([113.5,130],[25,25],color="black")

#Left 6-yard Box
plt.plot([0,5.5],[54,54],color="black")
plt.plot([5.5,5.5],[54,36],color="black")
plt.plot([5.5,0.5],[36,36],color="black")

#Right 6-yard Box
plt.plot([130,124.5],[54,54],color="black")
plt.plot([124.5,124.5],[54,36],color="black")
plt.plot([124.5,130],[36,36],color="black")

#Prepare Circles
centreCircle = plt.Circle((65,45),9.15,color="black",fill=False)
centreSpot = plt.Circle((65,45),0.8,color="black")
leftPenSpot = plt.Circle((11,45),0.8,color="black")
rightPenSpot = plt.Circle((119,45),0.8,color="black")

#Draw Circles
ax.add_patch(centreCircle)
ax.add_patch(centreSpot)
ax.add_patch(leftPenSpot)
ax.add_patch(rightPenSpot)

#Prepare Arcs
leftArc = Arc((11,45),height=18.3,width=18.3,angle=0,theta1=310,theta2=50,color="black")
rightArc = Arc((119,45),height=18.3,width=18.3,angle=0,theta1=130,theta2=230,color="black")

#Draw Arcs
ax.add_patch(leftArc)
ax.add_patch(rightArc)

#Tidy Axes
plt.axis('off')

for i in range(len(dribbles)):
    plt.plot([shots['X'],shots['X2']],[shots['Y'],shots['Y2']], color="blue")
    plt.plot(shots['X'],shots['Y'],"o", color="green")
plt.ylim(0, 90)
plt.xlim(0, 130)
plt.title("Anthony Elanga vs Wolves shots 23/5/21")


#Display Pitch
plt.show()

# %% [markdown]
# # Greenwood

# %%
utdful = pd.read_csv("D:/Matches/united_fulham_18052021.csv")

greenwood = utdful[utdful['Player'].isin(['Greenwood','HT'])]
greenwood.shape
# Out:
# (68, 9)

# %%
greenwood[greenwood['Player']=='HT']
# Out:
#        Team Player  Event  Mins  Secs   X   Y X2 Y2
# 38  Man Utd     HT  Touch     0    23  50  51  -  -

# %%
first_half_greenwood = greenwood.loc[:37,:]
second_half_greenwood = greenwood.loc[39:,:]
first_half_greenwood['X2'] = first_half_greenwood['X2'].replace('-', 0).astype(int)
first_half_greenwood['Y2'] = first_half_greenwood['Y2'].replace('-', 0).astype(int)
second_half_greenwood['X2'] = second_half_greenwood['X2'].replace('-', 0).astype(int)
second_half_greenwood['Y2'] = second_half_greenwood['Y2'].replace('-', 0).astype(int)
# Out:
# C:\Users\danny\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\danny\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\danny\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
#pre process data

first_half_greenwood['X'] = 100-first_half_greenwood['X']
second_half_greenwood['Y'] = 100-second_half_greenwood['Y']
first_half_greenwood['X2'] = 100-first_half_greenwood['X2']
second_half_greenwood['Y2'] = 100-second_half_greenwood['Y2']

greenwood_concat = pd.concat([first_half_greenwood, second_half_greenwood], axis=0, ignore_index=True)

greenwood_concat['X'] = greenwood_concat['X']*1.3
greenwood_concat['Y'] = greenwood_concat['Y']*0.9
greenwood_concat['X2'] = greenwood_concat['X2']*1.3
greenwood_concat['Y2'] = greenwood_concat['Y2']*0.9
# Out:
# C:\Users\danny\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\danny\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\danny\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
#Create figure
fig=plt.figure()
fig.set_size_inches(7, 5)
ax=fig.add_subplot(1,1,1)

#Pitch Outline & Centre Line
plt.plot([0,0],[0,90], color="black")
plt.plot([0,130],[90,90], color="black")
plt.plot([130,130],[90,0], color="black")
plt.plot([130,0],[0,0], color="black")
plt.plot([65,65],[0,90], color="black")

#Left Penalty Area
plt.plot([16.5,16.5],[65,25],color="black")
plt.plot([0,16.5],[65,65],color="black")
plt.plot([16.5,0],[25,25],color="black")

#Right Penalty Area
plt.plot([130,113.5],[65,65],color="black")
plt.plot([113.5,113.5],[65,25],color="black")
plt.plot([113.5,130],[25,25],color="black")

#Left 6-yard Box
plt.plot([0,5.5],[54,54],color="black")
plt.plot([5.5,5.5],[54,36],color="black")
plt.plot([5.5,0.5],[36,36],color="black")

#Right 6-yard Box
plt.plot([130,124.5],[54,54],color="black")
plt.plot([124.5,124.5],[54,36],color="black")
plt.plot([124.5,130],[36,36],color="black")

#Prepare Circles
centreCircle = plt.Circle((65,45),9.15,color="black",fill=False)
centreSpot = plt.Circle((65,45),0.8,color="black")
leftPenSpot = plt.Circle((11,45),0.8,color="black")
rightPenSpot = plt.Circle((119,45),0.8,color="black")

#Draw Circles
ax.add_patch(centreCircle)
ax.add_patch(centreSpot)
ax.add_patch(leftPenSpot)
ax.add_patch(rightPenSpot)

#Prepare Arcs
leftArc = Arc((11,45),height=18.3,width=18.3,angle=0,theta1=310,theta2=50,color="black")
rightArc = Arc((119,45),height=18.3,width=18.3,angle=0,theta1=130,theta2=230,color="black")

#Draw Arcs
ax.add_patch(leftArc)
ax.add_patch(rightArc)

#Tidy Axes
plt.axis('off')

sns.kdeplot(greenwood_concat["X"],greenwood_concat["Y"], shade=True,n_levels=20)
plt.ylim(0, 90)
plt.xlim(0, 130)
plt.title("Greenwood vs Fulham heatmap 18/5/21")


#Display Pitch
plt.show()
# Out:
# C:\Users\danny\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Get dribbles
greenwood_dribbles = greenwood_concat[greenwood_concat['Event'].str.contains('Dribble')].reset_index()

#Create figure
fig=plt.figure()
fig.set_size_inches(7, 5)
ax=fig.add_subplot(1,1,1)

#Pitch Outline & Centre Line
plt.plot([0,0],[0,90], color="black")
plt.plot([0,130],[90,90], color="black")
plt.plot([130,130],[90,0], color="black")
plt.plot([130,0],[0,0], color="black")
plt.plot([65,65],[0,90], color="black")

#Left Penalty Area
plt.plot([16.5,16.5],[65,25],color="black")
plt.plot([0,16.5],[65,65],color="black")
plt.plot([16.5,0],[25,25],color="black")

#Right Penalty Area
plt.plot([130,113.5],[65,65],color="black")
plt.plot([113.5,113.5],[65,25],color="black")
plt.plot([113.5,130],[25,25],color="black")

#Left 6-yard Box
plt.plot([0,5.5],[54,54],color="black")
plt.plot([5.5,5.5],[54,36],color="black")
plt.plot([5.5,0.5],[36,36],color="black")

#Right 6-yard Box
plt.plot([130,124.5],[54,54],color="black")
plt.plot([124.5,124.5],[54,36],color="black")
plt.plot([124.5,130],[36,36],color="black")

#Prepare Circles
centreCircle = plt.Circle((65,45),9.15,color="black",fill=False)
centreSpot = plt.Circle((65,45),0.8,color="black")
leftPenSpot = plt.Circle((11,45),0.8,color="black")
rightPenSpot = plt.Circle((119,45),0.8,color="black")

#Draw Circles
ax.add_patch(centreCircle)
ax.add_patch(centreSpot)
ax.add_patch(leftPenSpot)
ax.add_patch(rightPenSpot)

#Prepare Arcs
leftArc = Arc((11,45),height=18.3,width=18.3,angle=0,theta1=310,theta2=50,color="black")
rightArc = Arc((119,45),height=18.3,width=18.3,angle=0,theta1=130,theta2=230,color="black")

#Draw Arcs
ax.add_patch(leftArc)
ax.add_patch(rightArc)

#Tidy Axes
plt.axis('off')


for i in range(len(greenwood_dribbles)):
    plt.arrow(greenwood_dribbles['X'][i], greenwood_dribbles['Y'][i], greenwood_dribbles['X2'][i]-greenwood_dribbles['X'][i], greenwood_dribbles['Y2'][i]-greenwood_dribbles['Y'][i],  color='r', length_includes_head=True, head_width=1, head_length=1, width=0.25)

    
plt.ylim(0, 90)
plt.xlim(0, 130)
plt.title("Greenwood vs Fulham dribbles18/5/21 | Attacking to right")


#Display Pitch
plt.show()

# %%
#Create figure
fig=plt.figure()
fig.set_size_inches(7, 5)
ax=fig.add_subplot(1,1,1)

#Pitch Outline & Centre Line
plt.plot([0,0],[0,90], color="black")
plt.plot([0,130],[90,90], color="black")
plt.plot([130,130],[90,0], color="black")
plt.plot([130,0],[0,0], color="black")
plt.plot([65,65],[0,90], color="black")

#Left Penalty Area
plt.plot([16.5,16.5],[65,25],color="black")
plt.plot([0,16.5],[65,65],color="black")
plt.plot([16.5,0],[25,25],color="black")

#Right Penalty Area
plt.plot([130,113.5],[65,65],color="black")
plt.plot([113.5,113.5],[65,25],color="black")
plt.plot([113.5,130],[25,25],color="black")

#Left 6-yard Box
plt.plot([0,5.5],[54,54],color="black")
plt.plot([5.5,5.5],[54,36],color="black")
plt.plot([5.5,0.5],[36,36],color="black")

#Right 6-yard Box
plt.plot([130,124.5],[54,54],color="black")
plt.plot([124.5,124.5],[54,36],color="black")
plt.plot([124.5,130],[36,36],color="black")

#Prepare Circles
centreCircle = plt.Circle((65,45),9.15,color="black",fill=False)
centreSpot = plt.Circle((65,45),0.8,color="black")
leftPenSpot = plt.Circle((11,45),0.8,color="black")
rightPenSpot = plt.Circle((119,45),0.8,color="black")

#Draw Circles
ax.add_patch(centreCircle)
ax.add_patch(centreSpot)
ax.add_patch(leftPenSpot)
ax.add_patch(rightPenSpot)

#Prepare Arcs
leftArc = Arc((11,45),height=18.3,width=18.3,angle=0,theta1=310,theta2=50,color="black")
rightArc = Arc((119,45),height=18.3,width=18.3,angle=0,theta1=130,theta2=230,color="black")

#Draw Arcs
ax.add_patch(leftArc)
ax.add_patch(rightArc)

#Tidy Axes
plt.axis('off')

sns.kdeplot(greenwood_dribbles["X"],greenwood_dribbles["Y"], shade=True,n_levels=20)
plt.ylim(0, 90)
plt.xlim(0, 130)
plt.title("Greenwood vs Fulham dribble starting loc heatmap 18/5/21")


#Display Pitch
plt.show()
# Out:
# C:\Users\danny\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Create figure
fig=plt.figure()
fig.set_size_inches(7, 5)
ax=fig.add_subplot(1,1,1)

#Pitch Outline & Centre Line
plt.plot([0,0],[0,90], color="black")
plt.plot([0,130],[90,90], color="black")
plt.plot([130,130],[90,0], color="black")
plt.plot([130,0],[0,0], color="black")
plt.plot([65,65],[0,90], color="black")

#Left Penalty Area
plt.plot([16.5,16.5],[65,25],color="black")
plt.plot([0,16.5],[65,65],color="black")
plt.plot([16.5,0],[25,25],color="black")

#Right Penalty Area
plt.plot([130,113.5],[65,65],color="black")
plt.plot([113.5,113.5],[65,25],color="black")
plt.plot([113.5,130],[25,25],color="black")

#Left 6-yard Box
plt.plot([0,5.5],[54,54],color="black")
plt.plot([5.5,5.5],[54,36],color="black")
plt.plot([5.5,0.5],[36,36],color="black")

#Right 6-yard Box
plt.plot([130,124.5],[54,54],color="black")
plt.plot([124.5,124.5],[54,36],color="black")
plt.plot([124.5,130],[36,36],color="black")

#Prepare Circles
centreCircle = plt.Circle((65,45),9.15,color="black",fill=False)
centreSpot = plt.Circle((65,45),0.8,color="black")
leftPenSpot = plt.Circle((11,45),0.8,color="black")
rightPenSpot = plt.Circle((119,45),0.8,color="black")

#Draw Circles
ax.add_patch(centreCircle)
ax.add_patch(centreSpot)
ax.add_patch(leftPenSpot)
ax.add_patch(rightPenSpot)

#Prepare Arcs
leftArc = Arc((11,45),height=18.3,width=18.3,angle=0,theta1=310,theta2=50,color="black")
rightArc = Arc((119,45),height=18.3,width=18.3,angle=0,theta1=130,theta2=230,color="black")

#Draw Arcs
ax.add_patch(leftArc)
ax.add_patch(rightArc)

#Tidy Axes
plt.axis('off')

sns.kdeplot(greenwood_dribbles["X2"],greenwood_dribbles["Y2"], shade=True,n_levels=20)
plt.ylim(0, 90)
plt.xlim(0, 130)
plt.title("Greenwood vs Fulham dribble starting loc heatmap 18/5/21")


#Display Pitch
plt.show()
# Out:
# C:\Users\danny\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Get dribbles
greenwood_dribbles = greenwood_concat[greenwood_concat['Event'].str.contains('Dribble')].reset_index()

#Create figure
fig=plt.figure()
fig.set_size_inches(7, 5)
ax=fig.add_subplot(1,1,1)

#Pitch Outline & Centre Line
plt.plot([0,0],[0,90], color="black")
plt.plot([0,130],[90,90], color="black")
plt.plot([130,130],[90,0], color="black")
plt.plot([130,0],[0,0], color="black")
plt.plot([65,65],[0,90], color="black")

#Left Penalty Area
plt.plot([16.5,16.5],[65,25],color="black")
plt.plot([0,16.5],[65,65],color="black")
plt.plot([16.5,0],[25,25],color="black")

#Right Penalty Area
plt.plot([130,113.5],[65,65],color="black")
plt.plot([113.5,113.5],[65,25],color="black")
plt.plot([113.5,130],[25,25],color="black")

#Left 6-yard Box
plt.plot([0,5.5],[54,54],color="black")
plt.plot([5.5,5.5],[54,36],color="black")
plt.plot([5.5,0.5],[36,36],color="black")

#Right 6-yard Box
plt.plot([130,124.5],[54,54],color="black")
plt.plot([124.5,124.5],[54,36],color="black")
plt.plot([124.5,130],[36,36],color="black")

#Prepare Circles
centreCircle = plt.Circle((65,45),9.15,color="black",fill=False)
centreSpot = plt.Circle((65,45),0.8,color="black")
leftPenSpot = plt.Circle((11,45),0.8,color="black")
rightPenSpot = plt.Circle((119,45),0.8,color="black")

#Draw Circles
ax.add_patch(centreCircle)
ax.add_patch(centreSpot)
ax.add_patch(leftPenSpot)
ax.add_patch(rightPenSpot)

#Prepare Arcs
leftArc = Arc((11,45),height=18.3,width=18.3,angle=0,theta1=310,theta2=50,color="black")
rightArc = Arc((119,45),height=18.3,width=18.3,angle=0,theta1=130,theta2=230,color="black")

#Draw Arcs
ax.add_patch(leftArc)
ax.add_patch(rightArc)

#Tidy Axes
plt.axis('off')



plt.arrow(greenwood_dribbles['X'].median(), greenwood_dribbles['Y'].median(), greenwood_dribbles['X2'].median()-greenwood_dribbles['X'].median(), greenwood_dribbles['Y2'].median()-greenwood_dribbles['Y'].median(),  color='r', length_includes_head=True, head_width=1, head_length=1, width=0.25)
ax.annotate("Greenwood",
            xy=(greenwood_dribbles['X'].median(), greenwood_dribbles['Y'].median())
            )
plt.arrow(dribbles['X'].median(), dribbles['Y'].median(), dribbles['X2'].median()-dribbles['X'].median(), dribbles['Y2'].median()-dribbles['Y'].median(),  color='r', length_includes_head=True, head_width=1, head_length=1, width=0.25)
ax.annotate("Elanga",
            xy=(dribbles['X'].median(), dribbles['Y'].median())
            )
    
plt.ylim(0, 90)
plt.xlim(0, 130)
plt.title("Greenwood vs Elanga avg dribble | Attacking to right")


#Display Pitch
plt.show()
